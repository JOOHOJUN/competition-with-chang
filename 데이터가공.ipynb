# %%
import urllib.parse as parse
import json

location = "경상남도 거제시 남부면 다대리"
parsing_location_for_url = parse.quote(location)
data = urllib.request.urlopen("http://maps.googleapis.com/maps/api/geocode/json?sensor=false&language=ko&address=" + parsing_location_for_url)
json = json.loads(data.read())

# %%
query
# Out:
# {'examParam1': ['value1'], 'examParam2': ['한글']}

# %%
urllib.parse.urlencode(query, doseq=True)
# Out:
# 'examParam1=value1&examParam2=%ED%95%9C%EA%B8%80'

# %%
import requests

# %%
인증키 = "8EC7B0A8-A9EF-36D2-B3DB-E0E1602C253B"
지역주소  = parse.quote("경기도 안양시 동안구 관양동 1588-8")

# %%
완성주소 = "http://api.vworld.kr/req/address?\
service=address&request=getcoord&version=2.0&crs=epsg:4326&\
address=%ED%9A%A8%EB%A0%B9%EB%A1%9C72%EA%B8%B8%2060&\
refine=false&simple=false&format=json&type=PARCEL&\
key="+인증키

# %%
완정주소 = "http://api.vworld.kr/req/address?service=address&request=getcoord&version=2.0&crs=epsg:4326&address=%ED%9A%A8%EB%A0%B9%EB%A1%9C72%EA%B8%B8%2060&refine=true&simple=false&format=xml&type=road&key="+인증키

# %%
a = requests.get(완성주소)

# %%
완성주소
# Out:
# 'http://api.vworld.kr/req/address?service=address&request=getcoord&version=2.0&crs=epsg:4326&address=%ED%9A%A8%EB%A0%B9%EB%A1%9C72%EA%B8%B8%2060&refine=false&simple=false&format=json&type=PARCEL&key=8EC7B0A8-A9EF-36D2-B3DB-E0E1602C253B'

# %%
a.headers
# Out:
# {'Date': 'Thu, 30 Jul 2020 11:25:05 GMT', 'Server': 'Apache', 'Set-Cookie': 'SCOUTER=x5vahvetn25kof; Expires=Tue, 17-Aug-2088 14:39:29 GMT, JSESSIONID=743C99A31FD88CFC3F776DE759E6E324.api2_svr_11; Version=1; Path="/"; HttpOnly', 'Content-Length': '241', 'Keep-Alive': 'timeout=5, max=100', 'Connection': 'Keep-Alive', 'Content-Type': 'application/json;charset=UTF-8'}

# %%
a.content
# Out:
# b'{"response" : {"service" : {"name" : "address", "version" : "2.0", "operation" : "getcoord", "time" : "303(ms)"}, "status" : "NOT_FOUND", "record" : {"total" : "0", "current" : "0"}, "page" : {"total" : "1", "current" : "1", "size" : "10"}}}'

# %%
### 카카오다음

# %%
from urllib.parse import urlparse
from tqdm import tqdm
import requests
import pandas as pd
import geopandas as gpd

# %%
# 네이버 API를 이용하여 결과 확인
# 인증키
client_id = "2i97c1gwlo"
client_secret = "gQxnZHLUg2Nxyl31T2vbGrF1tehvKsRdJ7rNhpIC"

# %%
#df2014 = pd.read_excel("./sudden_cardiac_arrest/data1418.xls", sheet_name="data14", encoding="utf-8")

#address = parse.quote("전라남도 담양군 월산면 오성리")
address = "전라남도 담양군 월산면 오성리"
#url = "https://naveropenapi.apigw.ntruss.com/map-geocode/v2/geocode?query=" + address
url = "https://naveropenapi.apigw.ntruss.com/map-geocode/v2/geocode?query="+address
res = requests.get(urlparse(url).geturl(), headers={"X-NCP-APIGW-API-KEY-ID":client_id,
"X-NCP-APIGW-API-KEY":client_secret})
df1_obj = res.json()

# %%
df1_obj
# Out:
# {'status': 'OK',
#  'meta': {'totalCount': 1, 'page': 1, 'count': 1},
#  'addresses': [{'roadAddress': '전라남도 담양군 월산면 오성리',
#    'jibunAddress': '전라남도 담양군 월산면 오성리',
#    'englishAddress': 'Oseong-ri, Wolsan-myeon, Damyang-gun, Jeollanam-do, Republic of Korea',
#    'addressElements': [{'types': ['SIDO'],
#      'longName': '전라남도',
#      'shortName': '전라남도',
#      'code': ''},
#     {'types': ['SIGUGUN'], 'longName': '담양군', 'shortName': '담양군', 'code': ''},
#     {'types': ['DONGMYUN'], 'longName': '월산면', 'shortName': '월산면', 'code': ''},
#     {'types': ['RI'], 'longName': '오성리', 'shortName': '오성리', 'code': ''},
#     {'types': ['ROAD_NAME'], 'longName': '', 'shortName': '', 'code': ''},
#     {'types': ['BUILDING_NUMBER'],
#      'longName': '',
#      'shortName': '',
#      'code': ''},
#     {'types': ['BUILDING_NAME'], 'longName': '', 'shortName': '', 'code': ''},
#     {'types': ['LAND_NUMBER'], 'longName': '', 'shortName': '', 'code': ''},
#     {'types': ['POSTAL_CODE'], 'longName': '', 'shortName': '', 'code': ''}],
#    'x': '126.9658',
#    'y': '35.3621',
#    'distance': 0.0}],
#  'errorMessage': ''}

# %% [markdown]
# ## google api

# %%
import pandas as pd
import requests
import json

from IPython.display import clear_output

# %%
시트 = '치유숲'
원본데이터 = pd.read_excel(r'K:\내 드라이브\산림빅데이터(희창)/포레스트 컴패스 데이터.xlsx',sheet_name=시트)
저장할데이터 = 원본데이터[['세부주소',시트+'명']].dropna().drop_duplicates()

# %%
len(저장할데이터)
# Out:
# 30

# %%
요청주소 = "https://maps.googleapis.com/maps/api/geocode/json?address={}&key={}".format
저장할데이터['위치정보'] = ''

# %%
for 인덱스 in 저장할데이터.index[:]:
    소재지 = 저장할데이터.loc[인덱스]['세부주소']
    응답정보 = requests.get(요청주소(소재지,'AIzaSyDWNnAjdudWlejoZ7mSq8EzU115OzuLHUw'))
    저장할데이터.loc[인덱스,'위치정보'] = 응답정보.content
    clear_output()
    print(인덱스)
# Out:
# 29

# %%
import pickle
with open(r'K:\내 드라이브\산림빅데이터(희창)\데이터정제/'+시트+'_위도경도및주소.bin','wb') as f:
    pickle.dump(저장할데이터,f)

# %%
import pickle
import json

# %%
def 위치정보에서경도위도가져오기(위치정보):
    임시정보 = json.loads(위치정보)
    위도 =임시정보['results'][0]['geometry']['location']['lat'] #위도
    경도 = 임시정보['results'][0]['geometry']['location']['lng'] #경도
    
    return 경도, 위도

# %%
#시트리스트   - 명산 산 치유숲 숙박시설 관광체험 음식점 휴양림 전통숲
#위도경도 필요한 시트   산 치유숲 휴양림 전통숲

# %%
시트 = '전통숲'

# %%
with open(r'K:\내 드라이브\산림빅데이터(희창)\데이터정제/'+시트+'_위도경도및주소.bin','rb') as f:
    저장할데이터 = pickle.load(f)
저장할데이터['경도'] = ''
저장할데이터['위도'] = ''

# %%
for 인덱스 in 저장할데이터.index:
    try:
        저장할데이터.loc[인덱스,'경도'], 저장할데이터.loc[인덱스,'위도'] = 위치정보에서경도위도가져오기(저장할데이터['위치정보'].loc[인덱스])
    except IndexError:
        print(저장할데이터.loc[인덱스,'세부주소'])
    
저장할데이터 = 저장할데이터[저장할데이터['위도'].apply(lambda x: True if x !='' else False)]
# Out:
# 강원도 춘천시 남면 가정3리 산15
# 전라북도 장수군 천천면 봉덕리 고금 305
# 전라북도 장수군 천천면 용광리 광산 490
# 경상북도 포항시 북구 송라면 광천1리 695-6
# 전라남도 순천시 월등면 장선리 농곡
# 강원도 고성군 거진읍 대대1리 509-19, 510-8
# 전라북도 장수군 장수읍 동촌리 동촌 439-2
# 충남 공주시 유구읍 신영1리 새말숲
# 충남 공주시 유구읍 백교2리(여러집에 의한 사유)
# 전라북도 장수군 계북면 매계리 매계 237-1
# 전라북도 장수군 장계면 명덕리 명덕 1644
# 전라북도 장수군 천천면 월곡리 반월 218-3
# 경기도 양평군 단월면 보룡1리 327-1
# 경기도 양평군 청운면 다대2리 298-4
# 경상북도 청송군 안덕면 문거1리 314-1
# 전라북도 장수군 장수읍 용계리 안양 779
# 전라북도 장수군 계남면 신전리 양신 1064-1
# 경상북도 봉화군 법전면 풍정2리 614
# 전라북도 장수군 계북면 농소리 연동 531-2
# 전라북도 장수군 장수읍 용계리 용계 438-3
# 전라남도 순천시 낙안면 용두리 용능
# 경상북도 의성군 점곡면 윤암2리 1153
# 전라북도 장수군 장수읍 송천리 이교 1457-1
# 강원도 속초시 설악동 589-1(임)
# 전라북도 장수군 천천면 장판리 장척 산23-2
# 경상북도 청송군 파천면 관1리 933-2구
# 전라남도 해남군 해남읍 학동리 산793-2

# %%
import pickle
with open(r'K:\내 드라이브\산림빅데이터(희창)\데이터정제/'+시트+'_위도경도및주소.bin','wb') as f:
    pickle.dump(저장할데이터,f)

# %%
#명산 산 치유숲 숙박시설 관광체험 음식점 휴양림 전통숲

# %%
명산시트 = pd.read_excel(r'K:\내 드라이브\산림빅데이터(희창)\데이터정제/포레스트 컴패스 데이터(위도경도추가이전).xlsx',sheet_name='명산')
산시트 = pd.read_excel(r'K:\내 드라이브\산림빅데이터(희창)\데이터정제/포레스트 컴패스 데이터(위도경도추가이전).xlsx',sheet_name='산')

산시트 = 산시트.drop_duplicates(['산명'])
산시트 = 산시트.fillna('')

명산시트 = 명산시트[['명산']]
명산시트['명산유무'] = 1
명산시트.columns = ['산명','명산유무']

# %%
산시트 = pd.merge(산시트,명산시트,on='산명',how='left')
del 산시트['위도']
del 산시트['경도']

# %%
시트 = '산'
with open(r'K:\내 드라이브\산림빅데이터(희창)\데이터정제/'+시트+'_위도경도및주소.bin','rb') as f:
    산_위도 = pickle.load(f)


기존시트 = 기존시트.fillna('')

#다를게 없음
#기존시트 = pd.read_excel(r'K:\내 드라이브\산림빅데이터(희창)/포레스트 컴패스 데이터.xlsx',sheet_name=시트)

# %%
산시트 = pd.merge(산시트,산_위도,on=['세부주소','산명'])

# %%
#치유숲 숙박시설 관광체험 음식점 휴양림 전통숲

# %%
시트 = '치유숲'
with open(r'K:\내 드라이브\산림빅데이터(희창)\데이터정제/'+시트+'_위도경도및주소.bin','rb') as f:
    치유숲 = pickle.load(f)

#다를게 없음
#기존시트 = pd.read_excel(r'K:\내 드라이브\산림빅데이터(희창)/포레스트 컴패스 데이터.xlsx',sheet_name=시트)

# %%
시트 = '휴양림'
with open(r'K:\내 드라이브\산림빅데이터(희창)\데이터정제/'+시트+'_위도경도및주소.bin','rb') as f:
    휴양림 = pickle.load(f)

기존시트 = pd.read_excel(r'K:\내 드라이브\산림빅데이터(희창)/포레스트 컴패스 데이터.xlsx',sheet_name=시트)

del 기존시트['위도']
del 기존시트['경도']
기존시트 = 기존시트.fillna('')

휴양림 = pd.merge(기존시트,휴양림,on=['세부주소','휴양림명'],how='left')

# %%
시트 = '전통숲'
with open(r'K:\내 드라이브\산림빅데이터(희창)\데이터정제/'+시트+'_위도경도및주소.bin','rb') as f:
     전통숲 = pickle.load(f)

기존시트 = pd.read_excel(r'K:\내 드라이브\산림빅데이터(희창)/포레스트 컴패스 데이터.xlsx',sheet_name=시트)

del 기존시트['위도']
del 기존시트['경도']
기존시트 = 기존시트.fillna('')

전통숲 = pd.merge(기존시트,전통숲,on=['세부주소','전통숲명'],how='left')

# %%
전통숲
# Out:
#                                                  세부주소              전통숲명  \
# 0                                경기도 김포시 하성면 가금리 59-1           가금리 마을숲
# 1                                  충남 서천군 서천읍 삼산리 가루뫼              가루뫼숲
# 2                           경상남도 신등면 가술리 1125-1(가림마을)             가림마을숲
# 3                              전라남도 영광군 홍농읍 계마리 880-1            가마미마을숲
# 4                             경상북도 안동시 서후면 광평리 산 94번지               가야숲
# 5                                 강원도 춘천시 남면 가정3리 산15            가정 마을숲
# 6                                    전라북도 진안군 부귀면 신정리             가정마을숲
# 7                                  강원도 대화면 하안미리 394번지             가평마을숲
# 8                               강원도 양양군 강현면 석교리 267-3            간곡리마을숲
# 9                                    경상남도 거창군 북상면 농산리               갈계숲
# 10                               충청북도 괴산군 연풍면 갈금리 228             갈금리 숲
# 11                           경상남도 합천군 청덕면 가현리 299-3번지               갈마숲
# 12    경상북도 울진군 원남면 갈면리 508-1답, 508-2전, 508-7답, 508-8전           갈면리 마을숲
# 13                              경상북도 봉화군 법전면 풍정1리 818              갈방 숲
# 14                      경상남도 진주시 금산면 갈전리 1091번지(조동마을)          갈전숲(조동숲)
# 15                               강원도 양양군 서면 갈천리 118-2             갈천마을숲
# 11    조선 중종반정 후 영남학파 김종직선생의 제자들을 숙청(기묘사화)한 탐진(강진)안씨 ...
# 12
# 13
# 14    금산면 갈전리 조동마을의 서쪽에 있는 숲으로 1585년(선조 18년)경에 마을입구가...
# 15
# 16    1405년 (세종32년)에 진주소씨가 산을 개간하여 이곳에 정착 하였으며 견두산에서...
# 17    감산마을은 약 400년 전 형성되었으며, 마을 지명은 풍수지리상 말이 목을 축이는 ...
# 18
# 19    임씨성을 가진 사람들이 처음 들어와 마을을 이루고 살았으며 400여년전 어업에 의존...
# 20
# 21
# 22
# 23    진주시 정촌면 예하리 강주마을에 소재된 강주 연못 숲은 지금부터 약 90~100년전...
# 24
# 25
# 26    부귀산 자락의 좁은 골짜기에 형성된 마을 어귀에 수구맥이 목적으로 조성된 숲이다. ...
# 27    고증자료는 없으나 서기 850년전 고려 태조 왕건의 개국을 예언했던 도승이 장안을 ...
# 28    특별한 유래는 없으나 숲을 길러야 동네가 평안하다고 하여 마을입구에 자연적으로 조성...
# 29
# ...                                                 ...
# 1069
# 1070
# 1071
# 1072
# 1073
# 1074
# 1075
# 1076
# 1077                                            협재리 마을숲
# 1078  호구리의 속명은 ‘호구동’이다. 1350년경 길우마을 뒤 웡꿀(원동)에 진주하씨가 ...
# 1079     양양3형제 산봉우리가 내려와서 해망산이 됨(첫째 덕봉산, 둘째 해망산,셋째 비로봉)
# 1080  1981년 12월 21일 경상남도유형문화재 제198호로 지정됨. 상주주씨 문중이 소...
# 1081
# 1082
# 1083
# 1084
# 1085
# 1086  600년 전 우리 조상들이 동리 앞에 심어 놓은 100여 그루의 느티나무 숲은 무더...
# 1087
# 1088
# 1089                                                당산제
# 1090
# 1091
# 1092
# 1093
# 1094                         충혼탑,봉황정,봉황산은 삼척을 지키는 수호신이다
# 1095
# 1096
# 1097
# 1098
#
#                                                  문화조사내용  \
# 0
# 1
# 2
# 3     매년 7월 개장에 맞추어 행사를 가져 주민과 가마미해수욕장을 찾는 피서객에게 즐거움...
# 4
# 5                                         3년에 한번 제사를 지냄
# 6
# 7
# 8
# 9
# 10
# 11
# 12                                           동제 음력 1.15
# 13                                                 환경조절
# 14    숲 내에는 올래된 고목이 무성하여 경치가 좋아 사람들의 봄, 여름, 가을 할 것 없...
# 15
# 16
# 17                            당산제를 매년 음력 정월 초나흘에 지내고 있음
# 18
# 19    예전부터 마을의 대소상시 주민화합과 부조를 목적으로 하는 상조계 및 연말 주민결산총...
# 20
# 21
# 22
# 23    강주연못은 고려시대 강주진(康州鎭)이 있었던 곳으로 전하여지는 유서 깊은 곳이며, ...
# 24
# 25
# 26
# 27    마을안에 2201부대3대대가 위치해 있으며, 문화재로는 중요민속자료 제134호인 선...
# 28                            마을 주민들이 모여 동고사 지내고 있지는 않음
# 29
# ...                                                 ...
# 1069
# 1070
# 1071
# 1072
# 1073
# 1074
# 1075
# 1076
# 1077
# 1078  마을숲에서 매년 정월에 모든 마을주민들이 모여 그해 마을의 액운을 막고 풍년을 기원...
# 1079                                                풍어제
# 1080
# 1081
# 1082  홍계 마을 뒷산 기슭에는 수백년 생 소나무 당산목이 있어 매년 음력 이월 초승에 좋...
# 1083
# 1084
# 1085
# 1086
# 1087
# 1088
# 1089                                      아름다운전통마을숲대회응모
# 1090
# 1091
# 1092
# 1093
# 1094                                           현충일 기념행사
# 1095
# 1096
# 1097
# 1098                                      양귀비 축제(매년 6월)
#
#                                                    위치정보       경도       위도
# 0     b'{\n   "results" : [\n      {\n         "addr...  126.607  37.7455
# 1     b'{\n   "results" : [\n      {\n         "addr...  126.718  36.0656
# 2     b'{\n   "results" : [\n      {\n         "addr...  128.018  35.3943
# 3     b'{\n   "results" : [\n      {\n         "addr...   126.42  35.4065
# 4     b'{\n   "results" : [\n      {\n         "addr...  128.681  36.6508
# 5                                                   NaN      NaN      NaN
# 6     b'{\n   "results" : [\n      {\n         "addr...  127.344  35.7932
# 7     b'{\n   "results" : [\n      {\n         "addr...  128.472  37.4477
# 8     b'{\n   "results" : [\n      {\n         "addr...   128.57  38.1243
# 9     b'{\n   "results" : [\n      {\n         "addr...  127.807  35.7733
# 10    b'{\n   "results" : [\n      {\n         "addr...  127.958  36.7803
# 11    b'{\n   "results" : [\n      {\n         "addr...  128.334  35.5711
# 12    b'{\n   "results" : [\n      {\n         "addr...  129.341  36.8638
# 13    b'{\n   "results" : [\n      {\n         "addr...  128.845  36.9077
# 14    b'{\n   "results" : [\n      {\n         "addr...  128.163   35.188
# 15    b'{\n   "results" : [\n      {\n         "addr...    128.5  37.9123
# 16    b'{\n   "results" : [\n      {\n         "addr...  127.379  35.3288
# 17    b'{\n   "results" : [\n      {\n         "addr...  126.532  35.0687
# 18    b'{\n   "results" : [\n      {\n         "addr...  126.681  35.5743
# 19    b'{\n   "results" : [\n      {\n         "addr...  126.258   34.403
# 20    b'{\n   "results" : [\n      {\n         "addr...  129.577  36.0533
# 21    b'{\n   "results" : [\n      {\n         "addr...  128.593  38.1548
# 22    b'{\n   "results" : [\n      {\n         "addr...  128.599  38.1513
# 23    b'{\n   "results" : [\n      {\n         "addr...  128.096  35.1146
# 24    b'{\n   "results" : [\n      {\n         "addr...  127.395  34.8856
# 25    b'{\n   "results" : [\n      {\n         "addr...  127.808  35.8269
# 26    b'{\n   "results" : [\n      {\n         "addr...  127.387  35.7964
# 27    b'{\n   "results" : [\n      {\n         "addr...   127.79  36.4692
# 28    b'{\n   "results" : [\n      {\n         "addr...  127.797   36.719
# 29    b'{\n   "results" : [\n      {\n         "addr...  127.469  35.1255
# ...                                                 ...      ...      ...
# 1069  b'{\n   "results" : [\n      {\n         "addr...  129.021  36.2601
# 1070  b'{\n   "results" : [\n      {\n         "addr...  129.027  36.2754
# 1071  b'{\n   "results" : [\n      {\n         "addr...  129.039  36.2532
# 1072  b'{\n   "results" : [\n      {\n         "addr...  129.043  36.2444
# 1073  b'{\n   "results" : [\n      {\n         "addr...  128.899  36.2269
# 1074  b'{\n   "results" : [\n      {\n         "addr...  128.921  36.2889
# 1075  b'{\n   "results" : [\n      {\n         "addr...  128.953  36.2107
# 1076  b'{\n   "results" : [\n      {\n         "addr...   126.79  35.7267
# 1077  b'{\n   "results" : [\n      {\n         "addr...  126.248  33.3807
# 1078  b'{\n   "results" : [\n      {\n         "addr...  126.235  34.4244
# 1079  b'{\n   "results" : [\n      {\n         "addr...  129.333  37.1711
# 1080  b'{\n   "results" : [\n      {\n         "addr...  128.193  35.5702
# 1081  b'{\n   "results" : [\n      {\n         "addr...  127.114  36.0445
# 1082  b'{\n   "results" : [\n      {\n         "addr...  129.323  35.9468
# 1083  b'{\n   "results" : [\n      {\n         "addr...    126.7  35.2359
# 1084  b'{\n   "results" : [\n      {\n         "addr...  126.698  35.7617
# 1085  b'{\n   "results" : [\n      {\n         "addr...  127.871  36.5432
# 1086  b'{\n   "results" : [\n      {\n         "addr...  127.837   36.144
# 1087  b'{\n   "results" : [\n      {\n         "addr...  126.702  36.4472
# 1088  b'{\n   "results" : [\n      {\n         "addr...  128.264  35.7877
# 1089  b'{\n   "results" : [\n      {\n         "addr...  127.614  34.7082
# 1090  b'{\n   "results" : [\n      {\n         "addr...  127.369  35.0785
# 1091  b'{\n   "results" : [\n      {\n         "addr...  127.379   35.097
# 1092  b'{\n   "results" : [\n      {\n         "addr...  129.376  36.2446
# 1093  b'{\n   "results" : [\n      {\n         "addr...  128.441  38.4596
# 1094  b'{\n   "results" : [\n      {\n         "addr...  129.168   37.436
# 1095  b'{\n   "results" : [\n      {\n         "addr...  127.494   35.109
# 1096  b'{\n   "results" : [\n      {\n         "addr...  128.863   37.743
# 1097  b'{\n   "results" : [\n      {\n         "addr...  128.862  37.7427
# 1098  b'{\n   "results" : [\n      {\n         "addr...  127.941  37.2839
#
# [1099 rows x 9 columns]

# %%
경로 = r'K:\내 드라이브\산림빅데이터(희창)/포레스트 컴패스 데이터(최종).xlsx'
writer = pd.ExcelWriter(경로, engine = 'xlsxwriter')

산시트.to_excel(writer,sheet_name='산')
치유숲.to_excel(writer,sheet_name='치유숲')
휴양림.to_excel(writer,sheet_name='휴양림')
전통숲.to_excel(writer,sheet_name='전통숲')


#숙박시설 관광체험 음식점
숙박시설 = pd.read_excel(r'K:\내 드라이브\산림빅데이터(희창)\데이터정제/포레스트 컴패스 데이터(위도경도추가이전).xlsx',sheet_name='숙박시설').fillna('')
숙박시설.to_excel(writer,sheet_name='숙박시설')

관광체험 = pd.read_excel(r'K:\내 드라이브\산림빅데이터(희창)\데이터정제/포레스트 컴패스 데이터(위도경도추가이전).xlsx',sheet_name='관광체험').fillna('')
관광체험.to_excel(writer,sheet_name='관광체험')

전통숲 = pd.read_excel(r'K:\내 드라이브\산림빅데이터(희창)\데이터정제/포레스트 컴패스 데이터(위도경도추가이전).xlsx',sheet_name='전통숲').fillna('')
전통숲.to_excel(writer,sheet_name='전통숲')

writer.save()
writer.close()

# %%
from scipy.spatial import distance
round(distance.euclidean((126.97843, 37.56668), (127.02758, 37.49794)),5)
